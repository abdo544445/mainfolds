# %%
# !pip install numpy matplotlib scipy pynput pygame

import pygame
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import splprep, splev
from pynput.mouse import Listener

# Initialize variables
mouse_path = []  # List to store mouse coordinates
recording = False
screen_width = 800
screen_height = 600
colors = plt.cm.get_cmap('hsv', 256)  # Rainbow colormap for drawing

def on_click(x, y, button, pressed):
    global recording
    if button == btn.left:
        if pressed:
            recording = True
            mouse_path.clear()  # Clear path on left click start
        else:
            recording = False
            save_data("my_data")  # Save data on left click stop

def on_move(x, y):
    if recording:
        mouse_path.append((x, y))

def save_data(filename):
    # Convert mouse path to NumPy array
    path_array = np.array(mouse_path)

    # Smooth the path
    smoothed_path = smooth_lines(path_array)

    # Save original and smoothed paths to CSV files
    np.savetxt(f"{filename}_original.csv", path_array, delimiter=",", fmt="%d")
    np.savetxt(f"{filename}_smoothed.csv", smoothed_path, delimiter=",", fmt="%d")


def smooth_lines(points, num_points=100):
    tck, u = splprep(points.T, s=0)
    new_points = splev(np.linspace(0, 1, num_points), tck)
    return new_points


def draw_button(text, pos, color, active_color, font, action=None):
    # Utility function to draw a button
    button_rect = pygame.Rect(pos[0], pos[1], 200, 50)
    mouse_over = button_rect.collidepoint(pygame.mouse.get_pos())
    bg_color = color if not mouse_over else active_color
    pygame.draw.rect(screen, bg_color, button_rect)
    text_surf = font.render(text, True, (0, 0, 0))
    text_rect = text_surf.get_rect(center=button_rect.center)
    screen.blit(text_surf, text_rect)
    if action is not None and mouse_over and pygame.mouse.get_pressed()[0]:
        action()  # Call the provided action function


def main():
    # Pygame initialization
    pygame.init()
    screen = pygame.display.set_mode((screen_width, screen_height))
    pygame.display.set_caption("Mouse Path Capture")
    clock = pygame.time.Clock()
    font = pygame.font.Font(None, 32)  # Font for button text

    # Button properties
    button_text = "End Your Next Beauty"
    button_pos = (screen_width // 2 - 100, screen_height - 70)
    button_color = (200, 200, 200)
    button_active_color = (150, 150, 150)

    # Main loop
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            on_click(*event.pos, event.button, event.type == pygame.MOUSEBUTTONDOWN)

        # Clear the screen
        screen.fill((255, 55, 55))  # Background color

        # Draw the path with rainbow colors
        if mouse_path:
            for i in range(len(mouse_path) - 1):
                start_pos, end_pos = mouse_path[i], mouse_path[i + 1]
                color_index = (i / len(mouse_path)) * 255
                color = colors(color_index)[:3]  # Extract RGB from colormap
                pygame.draw.line(screen, color, start_pos, end_pos,
# Out:
#   Cell In[3], line 92
#     pygame.draw.line(screen, color, start_pos, end_pos,
#                                                        ^
# SyntaxError: incomplete input

# %%
# !pip install numpy matplotlib scipy pynput pygame

import pygame
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import splprep, splev
from pynput.mouse import Listener

# Initialize variables
mouse_path = []  # List to store mouse coordinates
recording = False
screen_width = 800
screen_height = 600
colors = plt.cm.get_cmap('hsv', 256)  # Rainbow colormap for drawing


def on_click(x, y, button, pressed):
    global recording
    if button == btn.left:
        if pressed:
            recording = True
            mouse_path.clear()  # Clear path on left click start
        else:
            recording = False
            save_data("my_data")  # Save data on left click stop


def on_move(x, y):
    if recording:
        mouse_path.append((x, y))


def save_data(filename):
    # Convert mouse path to NumPy array
    path_array = np.array(mouse_path)

    # Smooth the path
    smoothed_path = smooth_lines(path_array)

    # Save original and smoothed paths to CSV files
    np.savetxt(f"{filename}_original.csv", path_array, delimiter=",", fmt="%d")
    np.savetxt(f"{filename}_smoothed.csv", smoothed_path, delimiter=",", fmt="%d")


def smooth_lines(points, num_points=100):
    tck, u = splprep(points.T, s=0)
    new_points = splev(np.linspace(0, 1, num_points), tck)
    return new_points


def draw_button(text, pos, color, active_color, font, action=None):
    # Utility function to draw a button
    button_rect = pygame.Rect(pos[0], pos[1], 200, 50)
    mouse_over = button_rect.collidepoint(pygame.mouse.get_pos())
    bg_color = color if not mouse_over else active_color
    pygame.draw.rect(screen, bg_color, button_rect)
    text_surf = font.render(text, True, (0, 0, 0))
    text_rect = text_surf.get_rect(center=button_rect.center)
    screen.blit(text_surf, text_rect)
    if action is not None and mouse_over and pygame.mouse.get_pressed()[0]:
        action()  # Call the provided action function


def end_recording():
    global recording
    recording = False
    save_data("my_data")  # Save data on button click


def main():
    # Pygame initialization
    pygame.init()
    screen = pygame.display.set_mode((screen_width, screen_height))
    pygame.display.set_caption("Mouse Path Capture")
    clock = pygame.time.Clock()
    font = pygame.font.Font(None, 32)  # Font for button text

    # Button properties
    button_text = "End Your Next Beauty"
    button_pos = (screen_width // 2 - 100, screen_height - 70)
    button_color = (200, 200, 200)
    button_active_color = (150, 150, 150)

    # Main loop
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            on_click(*event.pos, event.button, event.type == pygame.MOUSEBUTTONDOWN)

        # Clear the screen
        screen.fill((255, 55, 55))  # Background color

        # Draw the path with rainbow colors
        if mouse_path:
            for i in range(len(mouse_path) - 1):
                start_pos, end_pos = mouse_path[i], mouse_path[i + 1]
                color_index = (i / len(mouse_path)) * 255
                color = colors(color_index)[:3]  # Extract RGB from colormap
# Out:
# pygame 2.5.2 (SDL 2.28.2, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 14
#      12 screen_width = 800
#      13 screen_height = 600
# ---> 14 colors = plt.cm.get_cmap('hsv', 256)  # Rainbow colormap for drawing
#      17 def on_click(x, y, button, pressed):
#      18     global recording
#
# AttributeError: module 'matplotlib.cm' has no attribute 'get_cmap'

# %%
# !pip install numpy matplotlib scipy pynput pygame

import pygame
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import splprep, splev
from pynput.mouse import Listener

# Initialize variables
mouse_path = []  # List to store mouse coordinates
recording = False
screen_width = 800
screen_height = 600
colors = plt.cm.get_cmap('hsv', 256)  # Rainbow colormap for drawing (using get_cmap from colors)


def on_click(x, y, button, pressed):
    global recording
    if button == btn.left:
        if pressed:
            recording = True
            mouse_path.clear()  # Clear path on left click start
        else:
            recording = False
            save_data("my_data")  # Save data on left click stop


def on_move(x, y):
    if recording:
        mouse_path.append((x, y))


def save_data(filename):
    # Convert mouse path to NumPy array
    path_array = np.array(mouse_path)

    # Smooth the path
    smoothed_path = smooth_lines(path_array)

    # Save original and smoothed paths to CSV files
    np.savetxt(f"{filename}_original.csv", path_array, delimiter=",", fmt="%d")
    np.savetxt(f"{filename}_smoothed.csv", smoothed_path, delimiter=",", fmt="%d")


def smooth_lines(points, num_points=100):
    tck, u = splprep(points.T, s=0)
    new_points = splev(np.linspace(0, 1, num_points), tck)
    return new_points


def draw_button(text, pos, color, active_color, font, action=None):
    # Utility function to draw a button
    button_rect = pygame.Rect(pos[0], pos[1], 200, 50)
    mouse_over = button_rect.collidepoint(pygame.mouse.get_pos())
    bg_color = color if not mouse_over else active_color
    pygame.draw.rect(screen, bg_color, button_rect)
    text_surf = font.render(text, True, (0, 0, 0))
    text_rect = text_surf.get_rect(center=button_rect.center)
    screen.blit(text_surf, text_rect)
    if action is not None and mouse_over and pygame.mouse.get_pressed()[0]:
        action()  # Call the provided action function


def end_recording():
    global recording
    recording = False
    save_data("my_data")  # Save data on button click


def main():
    # Pygame initialization
    pygame.init()
    screen = pygame.display.set_mode((screen_width, screen_height))
    pygame.display.set_caption("Mouse Path Capture")
    clock = pygame.time.Clock()
    font = pygame.font.Font(None, 32)  # Font for button text

    # Button properties
    button_text = "End Your Next Beauty"
    button_pos = (screen_width // 2 - 100, screen_height - 70)
    button_color = (200, 200, 200)
    button_active_color = (150, 150, 150)

    # Main loop
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            on_click(*event.pos, event.button, event.type == pygame.MOUSEBUTTONDOWN)

        # Clear the screen
        screen.fill((255, 55, 55))  # Background color

        # Draw the path with rainbow colors
        if mouse_path:
            for i in range(len(mouse_path) - 1):
                start_pos, end_pos = mouse_path[i], mouse_path[i + 1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 14
#      12 screen_width = 800
#      13 screen_height = 600
# ---> 14 colors = plt.cm.get_cmap('hsv', 256)  # Rainbow colormap for drawing (using get_cmap from colors)
#      17 def on_click(x, y, button, pressed):
#      18     global recording
#
# AttributeError: module 'matplotlib.cm' has no attribute 'get_cmap'

# %%
# !pip install numpy matplotlib scipy pynput pygame

import pygame
import numpy as np
from scipy.interpolate import splprep, splev
from pynput.mouse import Listener

# Initialize variables
mouse_path = []  # List to store mouse coordinates
recording = False
screen_width = 800
screen_height = 600
line_color = (0, 0, 255)  # Blue color for lines

def on_click(x, y, button, pressed):
    global recording
    if button == btn.left:
        if pressed:
            recording = True
            mouse_path.clear()  # Clear path on left click start
        else:
            recording = False
            save_data("my_data")  # Save data on left click stop


def on_move(x, y):
    if recording:
        mouse_path.append((x, y))


def save_data(filename):
    # Convert mouse path to NumPy array
    path_array = np.array(mouse_path)

    # Smooth the path
    smoothed_path = smooth_lines(path_array)

    # Save original and smoothed paths to CSV files
    np.savetxt(f"{filename}_original.csv", path_array, delimiter=",", fmt="%d")
    np.savetxt(f"{filename}_smoothed.csv", smoothed_path, delimiter=",", fmt="%d")


def smooth_lines(points, num_points=100):
    tck, u = splprep(points.T, s=0)
    new_points = splev(np.linspace(0, 1, num_points), tck)
    return new_points


def draw_button(text, pos, color, active_color, font, action=None):
    # Utility function to draw a button
    button_rect = pygame.Rect(pos[0], pos[1], 200, 50)
    mouse_over = button_rect.collidepoint(pygame.mouse.get_pos())
    bg_color = color if not mouse_over else active_color
    pygame.draw.rect(screen, bg_color, button_rect)
    text_surf = font.render(text, True, (0, 0, 0))
    text_rect = text_surf.get_rect(center=button_rect.center)
    screen.blit(text_surf, text_rect)
    if action is not None and mouse_over and pygame.mouse.get_pressed()[0]:
        action()  # Call the provided action function


def end_recording():
    global recording
    recording = False
    save_data("my_data")  # Save data on button click


def main():
    # Pygame initialization
    pygame.init()
    screen = pygame.display.set_mode((screen_width, screen_height))
    pygame.display.set_caption("Mouse Path Capture")
    clock = pygame.time.Clock()
    font = pygame.font.Font(None, 32)  # Font for button text

    # Button properties
    button_text = "End Your Next Beauty"
    button_pos = (screen_width // 2 - 100, screen_height - 70)
    button_color = (200, 200, 200)
    button_active_color = (150, 150, 150)

    # Main loop
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            on_click(*event.pos, event.button, event.type == pygame.MOUSEBUTTONDOWN)

        # Clear the screen
        screen.fill((255, 255, 255))  # White background

        # Draw the path
        if mouse_path:
            for i in range(len(mouse_path) - 1):
                start_pos, end_pos = mouse_path[i], mouse_path[i + 1]
                pygame.draw.line(screen, line_color, start_pos, end_pos, 4)  # Draw line with set color

        #
